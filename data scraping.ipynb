# %% [markdown]
# ### Movie Recommender System Data Scraping

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### MovieLens

# %% [markdown]
# #### movies.dat

# %% [markdown]
# The file contains data on 3,883 movies in the format **MovieID::Title::Genres**.
#
#
# |Item    | Description    |
# |------ | ------|
# |MovieID    | an integer, ranging from 1 to 3952, that identifies a movie   |
# |Title    | a String that concatenates movie title and year of release (between brackets)   |
# |Genres    | a list of genres    |
#
# First step is to read the movies dataset into a pandas dataframe.

# %%
# Load in the dataset
movies = pd.read_csv('movies.dat', delimiter = '::', names = ['movieId', 'title', 'genres'],engine = 'python')

# %%
print('There are', movies.shape[0], 'movies in the dataset.')
# Out:
# There are 3883 movies in the dataset.

# %%
# Look at the dataframe
movies.head()
# Out:
#    movieId                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
# Check the data types
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
# movieId    3883 non-null int64
# title      3883 non-null object
# genres     3883 non-null object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %% [markdown]
# I will remove the year of release from the movie title in the movies dataframe and move to a newly created column.

# %%
# Add the release year to a new column
movies['year'] = movies['title'].str.extract('(\d\d\d\d)', expand=True)
# Remove the release year from the title
movies['title'] = movies['title'].astype(str).str[:-6]
# Remove parentheses in the title
movies['title'] = movies['title'].str.replace(r"\(.*\)","")

# %%
# Look at the first few rows again
movies.head()
# Out:
#    movieId                         title                        genres  year
# 0        1                    Toy Story    Animation|Children's|Comedy  1995
# 1        2                      Jumanji   Adventure|Children's|Fantasy  1995
# 2        3             Grumpier Old Men                 Comedy|Romance  1995
# 3        4            Waiting to Exhale                   Comedy|Drama  1995
# 4        5  Father of the Bride Part II                         Comedy  1995

# %% [markdown]
# ### Data Scraping

# %%
import omdb
import requests
import re
import json
import numpy as np
import pandas as pd

# %% [markdown]
# In order to create models for content based filtering I need additional information about the movies other than the user ratings. For this I will extract additional data on each movie from from the Internet Movie Database (IMDb), an online database of movie and television data and catalogues all relavent information relating to movies e.g. actors, director, runtime, plot summary, awards, trivia, etc..

# %% [markdown]
# ## OMDb Scraping

# %% [markdown]
# The OMDb API, is a free web service to obtain movie information, it will be used to scrape the relavent data from IMDb.
#
# First I will create a list of movies from the movies dataframe.

# %%
# Create a list
movies_list = list(movies.title)

print('There are', len(movies_list), 'movies in the list.\n')

# Let's look at the first few items in the list
movies_list[:10]
# Out:
# There are 3883 movies in the list.
# ['Toy Story ',
#  'Jumanji ',
#  'Grumpier Old Men ',
#  'Waiting to Exhale ',
#  'Father of the Bride Part II ',
#  'Heat ',
#  'Sabrina ',
#  'Tom and Huck ',
#  'Sudden Death ',
#  'GoldenEye ']

# %% [markdown]
# I will create empty lists to store the all the scraped information as well as just the movie information I am looking for. It is useful to store all the information so if I want to add new features in the future I will not have to scrape again.
#
# I will also create an empty list to store movie titles that do not return a result. This is because the information provided with the dataset states that the data may be incorrect- mispelling, incomplete, duplicated entries etc.

# %%
movie_info = []
feature_info = []
bad_movies = []

# %% [markdown]
# I am looking for information on IMDb movie title, plot summary, top actors, director, runtime, certificate and imdb score.

# %%
# OMDb url
url = 'http://www.omdbapi.com/?apikey=e3bdfa2c&t={}'


# Loop through the movies in the list
for movie in movies_list:
    
    movie = movie.replace(' ', '+')

    try:
        
        response = requests.get(url.format(movie))
        info = response.json()
        movie_info.append([info])
        
        title = info['Title']
        plot = info['Plot']
        actors = info['Actors']
        director = info['Director']
        runtime = int(info['Runtime'][:-4])
        cert = info['Rated']
        imdb = float(info['imdbRating'])
        
        feature_info.append([title, plot, actors, director, runtime, cert, imdb])
            
    except:
        
        # Movies that cannot be scrapped will be saved to bad_info for analysis
        bad_movies.append([movie])

# %%
print(len(feature_info), 'movies have been successfully scaped.')
print(len(bad_movies), 'movies have not been scraped.')
# Out:
# 2978 movies have been successfully scaped.
# 905 movies have not been scraped.

# %% [markdown]
# After the initial scrape using OMDb API- 2978 movies were successfully scraped 905 movies were not been scraped. let's look at the first few to try and determine why they couldn't be scraped.

# %%
bad_movies[:10]
# Out:
# [['American+President,+The+'],
#  ['City+of+Lost+Children,+The+'],
#  ['Usual+Suspects,+The+'],
#  ['Big+Green,+The+'],
#  ['Postino,+Il++'],
#  ['Confessional,+The++'],
#  ['Indian+in+the+Cupboard,+The+'],
#  ['Mis�rables,+Les+'],
#  ['Crossing+Guard,+The+'],
#  ['Juror,+The+']]

# %% [markdown]
# It can be seen that movie titles with transposed articles-
#
# - titles ending in
#     - , The
#     - , Les
#     - , L'
#     - , La
#     - etc.
# - both engligh and foreign names in the title
# - mispellings e.g. Mis\xe9rables
# - with numbers in place of letters e.g. Se7en
#
# I will also define a function to remove the transposed artisles from the end of the movie titles and appending them to the beginning.

# %%
def_list = [", The", ", Las", ", La", ", Les", ", An", ", A", ", Le", ", El", ", Der", ", Das",]

def amendTitle(title):

        if title.find(i) == -1:
            return title.rstrip()
        else:
            title = title.replace(i, '')
            title = str(i[2:]) + ' ' + title
            return title.rstrip()
        
for i in def_list:
    
    movies['title'] = movies['title'].apply(amendTitle)

# Create a new list of the movie titles and movieId
movies_list = list(movies.title)
movieID_list = list(movies.movieId)

print('Confirm that there are', len(movies_list), 'movies in the list.')
# Out:
# Confirm that there are 3883 movies in the list.

# %% [markdown]
# I will perform another scrape with the cleaned movie titles.

# %%
# Create new blank lists to store the scraped movie information
movie_info = []
feature_info = []
bad_movies = []

# Loop through the movies in the list
for movie in movies_list:
    
    movie = movie.replace(' ', '+')

    try:
        
        response = requests.get(url.format(movie))
        info = response.json()
        movie_info.append([info])
        
        title = info['Title']
        plot = info['Plot']
        actors = info['Actors']
        director = info['Director']
        runtime = int(info['Runtime'][:-4])
        cert = info['Rated']
        imdb = float(info['imdbRating'])
        
        feature_info.append([title, plot, actors, director, runtime, cert, imdb])
            
    except:
        
        # Movies that cannot be scrapped will be saved to bad_info for analysis
        bad_movies.append([movie])

# %%
print(len(feature_info), 'movies have been successfully scaped.')
print(len(bad_movies), 'movies have not been scraped.')
# Out:
# 3699 movies have been successfully scaped.
# 184 movies have not been scraped.

# %% [markdown]
# These 184 movies have to be amended manually in the MovieLens dataset. It was also seen that some correctly spelled movies titles still failed to be scraped. Looking at the raw json files on the online OMDb API it can be seen that these movies are missing one or more of the features - title, plot, actors, director, runtime, cert, imdb_rating, imdb_id or poster. Example below -
#
#
# To deal with these movies I included a try/except for each feature, replacing missing information with None. I have also added some additional features to scrape as they will become useful in the future. There are -
#
# IMDb Id - a unique identified for each movie that will be useful for future searches
# poster - this is a link to the poster artwork of the film, useful for displaying recomended movies in a more user friendly way
# I need to import the amended dataset to ensure that movies are scraped accurately. I will apply all the functions to clean the titles and create a new movies list.

# %%
# Create new blank lists to store the scraped movie information
movie_info = []
feature_info = []
bad_movies = []

# Loop through the movies in the list
for movie, ID in zip(movies_list, movieID_list):

    movie = movie.replace(' ', '+')
    
    try:
        
        response = requests.get(url.format(movie))
        info = response.json()
        movie_info.append([info])
        
        try:
            title = info['Title']
        except:
            title = None
        try:
            plot = info['Plot']
        except:
            plot = None
        try:
            actors = info['Actors']
        except:
            actors = None
        try:
            director = info['Director']
        except:
            director = None
        try:
            runtime = int(info['Runtime'][:-4])
        except:
            runtime = None
        try:
            cert = info['Rated']
        except:
            cert = None
        try:
            imdb = float(info['imdbRating'])
        except:
            imdb = None
        try:
            imdb_id = (info['imdbID'])
        except:
            imdb_id = None    
        try:
            poster = (info['Poster'])
        except:
            poster = None
        
        feature_info.append([ID, title, plot, actors, director, runtime, cert, imdb, imdb_id, poster])
            
    except:
        
        bad_movies.append(movie)

# %%
print(len(feature_info), 'movies have been successfully scraped.')
print(len(bad_movies), 'movies have not been scraped.')
# Out:
# 3883 movies have been successfully scraped.
# 0 movies have not been scraped.

# %% [markdown]
# All movies have now been successfully scraped from OMDb API, next I will convert the feature information into a new dataframe for further analysis.

# %%
# Create a dataframe from the scraped movie information
imdb = pd.DataFrame(feature_info, columns=['movieId', 'title', 'Plot', 'actors', 
                                           'director', 'runtime', 'cert', 'imdb_rating', 'imdb_id', 'poster'])

# %%
# Look at the dataframe in more detail
imdb
# Out:
#       movieId                                  title  \
# 0           1                              Toy Story
# 1           2                                Jumanji
# 2           3                       Grumpier Old Men
# 3           4                      Waiting to Exhale
# 4           5            Father of the Bride Part II
# 5           6                                   Heat
# 6           7                                Sabrina
# 7           8                           Tom and Huck
# 8           9                           Sudden Death
# 9          10                              GoldenEye
# 10         11                 The American President
# 11         12            Dracula: Dead and Loving It
# 12         13                                  Balto
# 13         14                                  Nixon
# 14         15                       Cutthroat Island
# 15         16                                 Casino
# 16         17                  Sense and Sensibility
# 17         18                             Four Rooms
# 18         19         Ace Ventura: When Nature Calls
# 19         20                            Money Train
# 20         21                             Get Shorty
# 21         22                                Copycat
# 22         23                              Assassins
# 23         24                                 Powder
# 24         25                      Leaving Las Vegas
# 25         26                                Othello
# 26         27                           Now and Then
# 27         28                             Persuasion
# 28         29              The City of Lost Children
# 29         30                         Shanghai Triad
# ...       ...                                    ...
# 3853     3923                      Return of the Fly
# 3854     3924                           Pajama Party
# 3855     3925                 Stranger Than Paradise
# 3856     3926        Voyage to the Bottom of the Sea
# 3857     3927                       Fantastic Voyage
# 3858     3928  Abbott and Costello Meet Frankenstein
# 3859     3929                          The Bank Dick
# 3860     3930                                   None
# 3861     3931                 The Giant Gila Monster
# 3862     3932                      The Invisible Man
# 3863     3933                      The Killer Shrews
# 3864     3934                                 Kronos
# 3878                                          Jay Roach    108.0      PG-13
# 3879                                   Darren Aronofsky    102.0          R
# 3880                                    Joel Schumacher    101.0          R
# 3881                                 Raymond De Felitta    108.0          R
# 3882                                          Rod Lurie    126.0          R
#
#       imdb_rating    imdb_id  \
# 0             8.3  tt0114709
# 1             6.9  tt0113497
# 2             6.6  tt0113228
# 3             5.8  tt0114885
# 4             6.0  tt0113041
# 5             8.2  tt0113277
# 6             7.7  tt0047437
# 7             5.6  tt0112302
# 8             5.7  tt0114576
# 9             7.2  tt0113189
# 10            6.8  tt0112346
# 11            5.8  tt0112896
# 12            7.1  tt0112453
# 13            7.1  tt0113987
# 14            5.6  tt0112760
# 15            8.2  tt0112641
# 16            7.7  tt0114388
# 17            6.8  tt0113101
# 18            6.4  tt0112281
# 19            5.6  tt0113845
# 20            6.9  tt0113161
# 21            6.6  tt0112722
# 22            6.3  tt0112401
# 23            6.6  tt0114168
# 24            7.5  tt0113627
# 25            6.9  tt0114057
# 26            6.8  tt0114011
# 27            7.5  tt0844330
# 28            7.6  tt0112682
# 29            7.2  tt0115012
# ...           ...        ...
# 3853          5.8  tt0053219
# 3854          4.5  tt0058440
# 3855          7.6  tt0088184
# 3856          6.1  tt0055608
# 3857          6.8  tt0060397
# 3858          7.6  tt0040068
# 3859          7.3  tt0032234
# 3860          NaN       None
# 3861          3.4  tt0052846
# 3862          7.7  tt0024184
# 3863          3.9  tt0052969
# 3864          5.8  tt0050610
# 3865          5.8  tt0050610
# 3866          7.3  tt0293508
# 3867          5.9  tt0088024
# 3868          5.7  tt0084695
# 3869          NaN       None
# 3870          NaN       None
# 3871          4.3  tt0091990
# 3872          4.6  tt0100663
# 3873          6.5  tt0215545
# 3874          6.2  tt0210584
# 3875          6.0  tt0259974
# 3876          5.1  tt0208988
# 3877          5.1  tt0208988
# 3878          7.0  tt0212338
# 3879          8.3  tt0180093
# 3880          7.0  tt0170691
# 3881          7.3  tt0202641
# 3882          7.0  tt0208874
#
#                                                  poster
# 0     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1     https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2     https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3     https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4     https://m.media-amazon.com/images/M/MV5BOTEyNz...
# 5     https://m.media-amazon.com/images/M/MV5BNDc0YT...
# 6     https://m.media-amazon.com/images/M/MV5BYmFlNT...
# 7     https://m.media-amazon.com/images/M/MV5BN2ZkZT...
# 8     https://m.media-amazon.com/images/M/MV5BN2NjYW...
# 9     https://m.media-amazon.com/images/M/MV5BMzk2OT...
# 10    https://m.media-amazon.com/images/M/MV5BMTI5ND...
# 11    https://m.media-amazon.com/images/M/MV5BZWQ0ZD...
# 12    https://m.media-amazon.com/images/M/MV5BMjBhNm...
# 13    https://m.media-amazon.com/images/M/MV5BNzBlOW...
# 14    https://m.media-amazon.com/images/M/MV5BMDg2YT...
# 15    https://m.media-amazon.com/images/M/MV5BMTcxOW...
# 16    https://m.media-amazon.com/images/M/MV5BNzk1Mj...
# 17    https://m.media-amazon.com/images/M/MV5BNDc3Y2...
# 18    https://m.media-amazon.com/images/M/MV5BNGFiYT...
# 19    https://m.media-amazon.com/images/M/MV5BYWZlMz...
# 20    https://m.media-amazon.com/images/M/MV5BMjAwOD...
# 21    https://m.media-amazon.com/images/M/MV5BYWUwND...
# 22    https://m.media-amazon.com/images/M/MV5BZGI1ND...
# 23    https://m.media-amazon.com/images/M/MV5BOGUzYz...
# 24    https://m.media-amazon.com/images/M/MV5BNDg3MD...
# 25    https://m.media-amazon.com/images/M/MV5BMTIxMz...
# 26    https://m.media-amazon.com/images/M/MV5BMTM2MD...
# 27    https://m.media-amazon.com/images/M/MV5BNjcxZm...
# 28    https://m.media-amazon.com/images/M/MV5BZGQxZD...
# 29    https://m.media-amazon.com/images/M/MV5BMTgyMz...
# ...                                                 ...
# 3853  https://m.media-amazon.com/images/M/MV5BNjg5Mj...
# 3854  https://m.media-amazon.com/images/M/MV5BMTc4MD...
# 3855  https://m.media-amazon.com/images/M/MV5BMDQ1OD...
# 3856  https://m.media-amazon.com/images/M/MV5BYzc0NG...
# 3857  https://m.media-amazon.com/images/M/MV5BMjdjZD...
# 3858  https://m.media-amazon.com/images/M/MV5BNTZiZT...
# 3859  https://m.media-amazon.com/images/M/MV5BYzQwNz...
# 3860                                               None
# 3861  https://m.media-amazon.com/images/M/MV5BNDExMz...
# 3862  https://m.media-amazon.com/images/M/MV5BYzMxOT...
# 3863  https://m.media-amazon.com/images/M/MV5BZTg0Zj...
# 3864  https://m.media-amazon.com/images/M/MV5BMGRhOW...
# 3865  https://m.media-amazon.com/images/M/MV5BMGRhOW...
# 3866  https://m.media-amazon.com/images/M/MV5BNDczNz...
# 3867  https://m.media-amazon.com/images/M/MV5BZGI1MT...
# 3868  https://m.media-amazon.com/images/M/MV5BMGIzNT...
# 3869                                               None
# 3870                                               None
# 3871  https://m.media-amazon.com/images/M/MV5BOWVkYT...
# 3872  https://m.media-amazon.com/images/M/MV5BMTQxNT...
# 3873  https://m.media-amazon.com/images/M/MV5BMTI2OD...
# 3874  https://m.media-amazon.com/images/M/MV5BMTgxMz...
# 3875  https://m.media-amazon.com/images/M/MV5BMjE2NT...
# 3876  https://m.media-amazon.com/images/M/MV5BMTkzMD...
# 3877  https://m.media-amazon.com/images/M/MV5BMTkzMD...
# 3878  https://m.media-amazon.com/images/M/MV5BMGNlMG...
# 3879  https://m.media-amazon.com/images/M/MV5BOTdiNz...
# 3880  https://m.media-amazon.com/images/M/MV5BMzRlZD...
# 3881  https://m.media-amazon.com/images/M/MV5BMTQ3MT...
# 3882  https://m.media-amazon.com/images/M/MV5BYTIzYT...
#
# [3883 rows x 10 columns]

# %% [markdown]
# Iam going to save the above scraped data to csv file named:(movies_full.csv)

# %%
#imdb.to_csv('movies_full.csv')

# %% [markdown]
# ### Summary

# %% [markdown]
# I sucessfully scraped the movie data from the Internet Movie Database using the OMDb API and intergrated it with the MovieLens datasets. I descibed the process for the data extraction, data cleaning and integration.
#
# Some of the major difficulties encountered were-
#
# - IMDb data extraction - needed to develop pre-processing routines to clean up the movie titles at several stages
# - Missing data - several titles were missing data and algorithms had to be amended to capture missing data
# - Matching IMDb and MovieLens movie titles - had to deal with special characters, mispellings, transposed articles, foreign and alternative titles. Some of these had to be amended manually which was time consuming.
